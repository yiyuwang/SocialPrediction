# %% [markdown]
# ## First Level Analysis for Social Prediction
#
# 2024 February
#
# *Yiyu Wang*

# %%
import os


import glob
import nibabel as nib
import numpy as np
import pandas as pd
import copy

import nilearn
from nilearn import datasets, plotting, image
from nilearn.image import smooth_img, resample_to_img, load_img, concat_imgs, mean_img, resample_img
from nilearn import plotting
from nilearn.masking import apply_mask
from nilearn.input_data import NiftiMasker
from nilearn.glm.first_level import FirstLevelModel
from nilearn.glm.second_level import SecondLevelModel
from scipy.stats import norm


import gzip

import seaborn as sns
import matplotlib.pyplot as plt

from os.path import join
# Out:
# /Users/yiyuwang/anaconda3/envs/neuroimaging_env/lib/python3.7/site-packages/nilearn/__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()
# /Users/yiyuwang/anaconda3/envs/neuroimaging_env/lib/python3.7/site-packages/nilearn/input_data/__init__.py:23: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
print(nilearn.__version__)
# Out:
# 0.10.2

# %%
# local directory set up
#data_dir =base_dir + 'transformed_data_2mm/'

# directory set up for cluster:
# base_dir = '/scratch/wang.yiyu/SocialAbstraction/'
data_dir = '/Users/yiyuwang/Downloads/social_prediction_transformed_data_2mm/'

logfiles_dir = 'Data/logfiles/'
confounds_dir = 'Data/confounds/'
mask_dir = 'masks/'
figures_dir = 'figures/'

subjects_list = pd.read_csv('Data/included_SocialPred_subjects.csv', header=None)
subjects_list = subjects_list[0].values.tolist()
sample_n = len(subjects_list)
print("subjects in this analysis:")
print(subjects_list)
print(f"**** n = {sample_n} *****" )

vmax = 12
TR = .001
N_TR = 675
TR_Length = 0.8
TR_IN_MS = int(TR_Length/TR)


# resample a gray matter mask
gm_mask_img = nib.load(mask_dir + 'gm_mask_icbm152_brain.nii.gz')
confounds_of_interest = ['csf',
                        'white_matter',
                        'trans_x', 
                        'trans_y', 
                        'trans_z',
                        'rot_x',
                        'rot_y',
                        'rot_z','framewise_displacement']
# Out:
# subjects in this analysis:
# [152, 179, 154, 158, 173, 153, 159, 174, 162, 145, 143, 181, 144, 169, 146, 167, 161, 182, 147, 166, 160, 185, 170, 176, 151, 157, 171, 177, 150, 156]
# **** n = 30 *****

# %%
logfile_headers =np.array(['obs_video_name', 'fd_video_name','video_number','trial_condition','run_number','run_condition',
             'obs_video_onset','obs_video_offset','obs_video_duration_method1','obs_video_duration_method2',
             'prediction','prediction_x','prediction_y','prediction_RT','prediction_onset', 
             'fb_video_onset','fb_video_offset','fb_video_duration_method1','fb_video_duration_method2',
             'surprise','surprise_RT','surprise_onset'])

# %%
def AddSteadyStateOutliers(columns_of_interest, all_columns):
    new_columns = copy.deepcopy(columns_of_interest)
    for column in all_columns:
        if 'outlier' in column:
            new_columns.append(column) 
    return new_columns



def CreateConfoundMatrix(confound_file_path, 
                         confounds_of_interest, s, run):
    
    
    confounds = pd.read_csv(confound_file_path, sep='\t')
    confounds_of_interest = AddSteadyStateOutliers(confounds_of_interest, confounds.columns)
    
    cov = confounds[confounds_of_interest]
    cov.values[np.isnan(cov.values)]=0
    return cov


video_key = pd.read_csv('/Users/yiyuwang/Dropbox/Projects/NEU_projects/SocialPrediction/Results/SocialPrediction_video_key.csv')


def get_subjective_prior(prediction, vn, video_key = video_key):
    social_prior = video_key[video_key.vid_num == vn]['Social_correct'].values[0]
    pattern_prior = video_key[video_key.vid_num == vn]['Pattern_correct'].values[0]
    if pattern_prior == 7:
        if prediction == 4 or prediction == 2:
            return 1, 'Pattern'
        elif prediction == social_prior:
            return 2, 'Social'
        else:
            return 0, 'Neither'
    elif pattern_prior == 8:
        if prediction == 3 or prediction == 2:
            return 1, 'Pattern'
        elif prediction == social_prior:
            return 2, 'Social'
        else:
            return 0, 'Neither'
    elif pattern_prior == 6:
        if prediction == 4 or prediction == 1:
            return 1, 'Pattern'
        elif prediction == social_prior:
            return 2, 'Social'
        else:
            return 0, 'Neither'
    else: 
        if prediction == social_prior:
            return 2, 'Social'
        elif prediction == pattern_prior:
            return 1, 'Pattern'
        else:
            return 0, 'Neither'

# %%
def get_condition(cn):
    if cn == 1:
        cat = 'Pattern'
    elif cn == 2:
        cat = 'Social'
    else:
        print('no such Condition number!')
    return cat 

def parse_task_lines(lines, headers):
    social_counts = 0
    pattern_counts = 0
    neither_counts = 0
    for (i, line) in enumerate(lines):
        cols = line.split(' ')

        video_number = cols[int(np.where(headers == 'video_number')[0])]
        
        trial_condition = int(cols[int(np.where(headers == 'trial_condition')[0])])
        trial_condition = get_condition(trial_condition)
        
        run_condition = int(cols[int(np.where(headers == 'run_condition')[0])])
        run_condition = get_condition(run_condition)

        prediction = int(abs(float(cols[int(np.where(headers == 'prediction')[0])])))
        
        _, subjective_prior_condition = get_subjective_prior(prediction, int(video_number))
        if subjective_prior_condition == 'Social':
            social_counts = social_counts +1
        elif subjective_prior_condition == 'Pattern':
            pattern_counts = pattern_counts + 1
        else:
            neither_counts = neither_counts + 1

        obs_trial_type = 'obs_' + subjective_prior_condition

        # modeling the fb_neither
        # congruent means trial_condition == run_condition
        if subjective_prior_condition == 'Pattern':
            if trial_condition == 'Pattern':
                fb_trial_type = 'fb_Pattern_Congruent'
            elif trial_condition == 'Social':
                fb_trial_type = 'fb_Pattern_PE'
            
        elif subjective_prior_condition == 'Social':
            if trial_condition == 'Social':
                fb_trial_type = 'fb_Social_Congruent'
            elif trial_condition == 'Pattern':
                fb_trial_type = 'fb_Social_PE'
                
        elif subjective_prior_condition == 'Neither':
            fb_trial_type = 'fb_Neither'
        else:
            print('no such trial type!')

        # do not modeling fb_neither, treat those as fb_PE to the trial condition, 
        # since the participant did not make congruent prediction to the trial condition
        # if subjective_prior_condition == trial_condition:
        #     if trial_condition == 'Pattern':
        #         fb_trial_type = 'fb_Pattern_Congruent'
        #     elif trial_condition == 'Social':
        #         fb_trial_type = 'fb_Social_Congruent'
            
        # else: # PE means trial_condition != subjective_prior_condition
        #     if trial_condition == 'Pattern':
        #         fb_trial_type = 'fb_Social_PE'
        #     elif trial_condition == 'Social':
        #         fb_trial_type = 'fb_Pattern_PE'
              
        video_onset = float(cols[int(np.where(headers == 'obs_video_onset')[0])])
        video_offset = float(cols[int(np.where(headers == 'obs_video_offset')[0])])  
        video_duration = video_offset - video_onset
        
        fb_video_onset = float(cols[int(np.where(headers == 'fb_video_onset')[0])])
        fb_video_offset = float(cols[int(np.where(headers == 'fb_video_offset')[0])])  
        fb_video_duration = fb_video_offset - fb_video_onset

        run = int(cols[int(np.where(headers == 'run_number')[0])])

        prediction_onset = float(cols[int(np.where(headers == 'prediction_onset')[0])])
        surprise_onset = float(cols[int(np.where(headers == 'surprise_onset')[0])])
        
        yield [video_onset, video_duration, obs_trial_type, run]
        yield [fb_video_onset,fb_video_duration, fb_trial_type, run]
        yield [surprise_onset, 1, 'surprise_onset', run]
        yield [prediction_onset, 1, 'pred_onset', run]


def create_events_dataframe(task_csv, run):   
    task_lines =[]       
    # df = pd.DataFrame(columns=['onset','duration','trial_type'])
    with open(task_csv, 'r') as task_csv_file:
        task_lines.append(list(parse_task_lines(task_csv_file.readlines()[0:], logfile_headers)))

    df = pd.DataFrame(task_lines[0], columns=['onset','duration','trial_type','run'])
    df= df[df['run']==run].drop(columns=['run'])
    return df

# %%
from nilearn.glm.first_level import make_first_level_design_matrix
from nilearn.glm.first_level import compute_regressor
model_name = 'model_5_final'
res_dir = f'Results/{model_name}/1stLvl'

create_design_matrix = True
if create_design_matrix: 

    if not os.path.isdir(res_dir):
        os.makedirs(res_dir)
    design_matrices = []
    sub_run_list = []
    for s in subjects_list:
        print(f'running subject {s}')
        sub_output_dir = res_dir + f'/{s}/'
        if not os.path.isdir(sub_output_dir):
            os.makedirs(sub_output_dir)
            
        task_file = glob.glob(logfiles_dir + f"/*{s}*edited.txt")
        task_csv = task_file[0]
        
        for run in [1,2]:
            sub_run_list.append(f'sub-{s}_run-{run}')
            events = create_events_dataframe(task_csv, run)

            #get confounds info:
            confounds_str = f'sub-{s}_task-socialpred_run-{run}_desc-confounds_timeseries.tsv'
            cov = CreateConfoundMatrix(confounds_dir + confounds_str, confounds_of_interest, s, run)
            
            fmri_glm = FirstLevelModel(t_r=TR_Length,
                        noise_model='ar3',
                        standardize=True,
                        hrf_model='spm',
                        drift_model='cosine',
                        high_pass=.012, mask_img=gm_mask_img,smoothing_fwhm=6)
            
            func_str = f'sub-{s}_socialpred_run{run}.nii.gz'
            func_path = data_dir + func_str
            fmri_img = nib.load(func_path)
            fmri_glm = fmri_glm.fit(fmri_img, events, confounds=cov)
            
            
            # save design_matrix for every run
            design_matrix = fmri_glm.design_matrices_[0]
            design_matrices.append(design_matrix)
            print(design_matrix.columns)
            plotting.plot_design_matrix(design_matrix, output_file=join(sub_output_dir, f'design_matrix_run{run}.png'))
            design_matrix.to_csv(join(sub_output_dir, f'sub-{s}_run-{run}_design_matrix.csv'))
            
        # save design_matrix
        design_matrix = fmri_glm.design_matrices_[0]
            

    # save design_matrices
    import pickle
    with open(res_dir + 'design_matrices.pkl', 'wb') as f:
        pickle.dump(design_matrices, f)

else: 
    design_matrices = []
    for s in subjects_list:
        sub_output_dir = res_dir + f'/{s}/'
        for run in [1,2]:
            design_matrices.append(pd.read_csv(join(sub_output_dir, f'sub-{s}_run-{run}_design_matrix.csv'), index_col=0))
# Out:
# running subject 152
# Index(['fb_Neither', 'fb_Pattern_PE', 'fb_Social_Congruent', 'fb_Social_PE',
#        'obs_Neither', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'motion_outlier00', 'motion_outlier01', 'motion_outlier02',
#        'motion_outlier03', 'motion_outlier04', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'motion_outlier03', 'motion_outlier04',
#        'motion_outlier05', 'motion_outlier06', 'motion_outlier07',
#        'motion_outlier08', 'motion_outlier09', 'motion_outlier10', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 179
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02',
#        'motion_outlier00', 'motion_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02',
#        'motion_outlier00', 'motion_outlier01', 'motion_outlier02',
#        'motion_outlier03', 'drift_1', 'drift_2', 'drift_3', 'drift_4',
#        'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9', 'drift_10',
#        'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 154
# Index(['fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_Congruent',
#        'fb_Social_PE', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'motion_outlier00', 'drift_1', 'drift_2',
#        'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8',
#        'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02',
#        'non_steady_state_outlier03', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 158
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02',
#        'motion_outlier00', 'motion_outlier01', 'motion_outlier02',
#        'motion_outlier03', 'motion_outlier04', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02',
#        'motion_outlier00', 'drift_1', 'drift_2', 'drift_3', 'drift_4',
#        'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9', 'drift_10',
#        'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 173
# Index(['fb_Pattern_Congruent', 'fb_Pattern_PE', 'obs_Pattern', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'motion_outlier03', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'motion_outlier00', 'motion_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 153
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 159
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_PE',
#        'obs_Neither', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'drift_1', 'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6',
#        'drift_7', 'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12',
#        'constant'],
#       dtype='object')
# Index(['fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_Congruent',
#        'fb_Social_PE', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'motion_outlier00', 'drift_1', 'drift_2', 'drift_3', 'drift_4',
#        'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9', 'drift_10',
#        'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 174
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 162
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 145
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_PE',
#        'obs_Neither', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 143
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Social_Congruent',
#        'fb_Social_PE', 'obs_Neither', 'obs_Pattern', 'obs_Social',
#        'pred_onset', 'surprise_onset', 'csf', 'white_matter', 'trans_x',
#        'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02',
#        'motion_outlier00', 'motion_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02',
#        'motion_outlier00', 'motion_outlier01', 'motion_outlier02', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 181
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'motion_outlier00', 'motion_outlier01', 'motion_outlier02',
#        'motion_outlier03', 'motion_outlier04', 'motion_outlier05',
#        'motion_outlier06', 'motion_outlier07', 'motion_outlier08',
#        'motion_outlier09', 'motion_outlier10', 'motion_outlier11',
#        'motion_outlier12', 'motion_outlier13', 'motion_outlier14',
#        'motion_outlier15', 'motion_outlier16', 'motion_outlier17',
#        'motion_outlier18', 'motion_outlier19', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'motion_outlier03', 'motion_outlier04',
#        'motion_outlier05', 'motion_outlier06', 'motion_outlier07',
#        'motion_outlier08', 'motion_outlier09', 'motion_outlier10',
#        'motion_outlier11', 'motion_outlier12', 'motion_outlier13',
#        'motion_outlier14', 'motion_outlier15', 'motion_outlier16', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 144
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 169
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_PE',
#        'obs_Neither', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'motion_outlier00', 'motion_outlier01',
#        'drift_1', 'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6',
#        'drift_7', 'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12',
#        'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 146
# Index(['fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_Congruent',
#        'fb_Social_PE', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 167
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'motion_outlier00', 'motion_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'motion_outlier00', 'drift_1', 'drift_2',
#        'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8',
#        'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 161
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'drift_1', 'drift_2', 'drift_3', 'drift_4',
#        'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9', 'drift_10',
#        'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'motion_outlier03', 'motion_outlier04',
#        'motion_outlier05', 'motion_outlier06', 'motion_outlier07', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 182
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'motion_outlier00', 'motion_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 147
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'motion_outlier03', 'motion_outlier04',
#        'motion_outlier05', 'motion_outlier06', 'motion_outlier07',
#        'motion_outlier08', 'motion_outlier09', 'motion_outlier10',
#        'motion_outlier11', 'motion_outlier12', 'motion_outlier13',
#        'motion_outlier14', 'drift_1', 'drift_2', 'drift_3', 'drift_4',
#        'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9', 'drift_10',
#        'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'motion_outlier00', 'motion_outlier01', 'motion_outlier02',
#        'motion_outlier03', 'motion_outlier04', 'motion_outlier05',
#        'motion_outlier06', 'motion_outlier07', 'motion_outlier08',
#        'motion_outlier09', 'motion_outlier10', 'motion_outlier11', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 166
# Index(['fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_Congruent',
#        'fb_Social_PE', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_Congruent',
#        'fb_Social_PE', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 160
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02',
#        'non_steady_state_outlier03', 'non_steady_state_outlier04',
#        'non_steady_state_outlier05', 'non_steady_state_outlier06',
#        'non_steady_state_outlier07', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_PE',
#        'obs_Neither', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01',
#        'non_steady_state_outlier02', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 185
# Index(['fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_Congruent',
#        'fb_Social_PE', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_PE', 'fb_Social_Congruent', 'fb_Social_PE',
#        'obs_Neither', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 170
# Index(['fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_Congruent',
#        'fb_Social_PE', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'drift_1', 'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6',
#        'drift_7', 'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12',
#        'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02',
#        'non_steady_state_outlier03', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 176
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'motion_outlier00', 'drift_1', 'drift_2', 'drift_3', 'drift_4',
#        'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9', 'drift_10',
#        'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 151
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Social_Congruent',
#        'fb_Social_PE', 'obs_Neither', 'obs_Pattern', 'obs_Social',
#        'pred_onset', 'surprise_onset', 'csf', 'white_matter', 'trans_x',
#        'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 157
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 171
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE', 'fb_Social_PE',
#        'obs_Neither', 'obs_Pattern', 'obs_Social', 'pred_onset',
#        'surprise_onset', 'csf', 'white_matter', 'trans_x', 'trans_y',
#        'trans_z', 'rot_x', 'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01',
#        'motion_outlier00', 'motion_outlier01', 'motion_outlier02',
#        'motion_outlier03', 'motion_outlier04', 'motion_outlier05',
#        'motion_outlier06', 'motion_outlier07', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 177
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'non_steady_state_outlier02',
#        'non_steady_state_outlier03', 'motion_outlier00', 'drift_1', 'drift_2',
#        'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8',
#        'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 150
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'motion_outlier00', 'drift_1', 'drift_2',
#        'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8',
#        'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'motion_outlier00', 'motion_outlier01', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 156
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'non_steady_state_outlier01', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'motion_outlier03', 'motion_outlier04',
#        'motion_outlier05', 'motion_outlier06', 'motion_outlier07',
#        'motion_outlier08', 'motion_outlier09', 'motion_outlier10', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# Index(['fb_Neither', 'fb_Pattern_Congruent', 'fb_Pattern_PE',
#        'fb_Social_Congruent', 'fb_Social_PE', 'obs_Neither', 'obs_Pattern',
#        'obs_Social', 'pred_onset', 'surprise_onset', 'csf', 'white_matter',
#        'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z',
#        'framewise_displacement', 'non_steady_state_outlier00',
#        'motion_outlier00', 'motion_outlier01', 'motion_outlier02', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')

# %%
dm_dir = f'Results/{model_name}/1stLvl'

design_matrices = []
for s in subjects_list:
    sub_output_dir = dm_dir + f'/{s}/'
    for run in [1,2]:
        design_matrices.append(pd.read_csv(join(sub_output_dir, f'sub-{s}_run-{run}_design_matrix.csv'), index_col=0))

            
design_index = 0

res_dir = f'Results/{model_name}/1stLvl'
if not os.path.isdir(res_dir):
    os.makedirs(res_dir)
column_names = ['obs_Pattern', 'obs_Social', 'fb_Pattern_Congruent', 'fb_Social_Congruent', 'fb_Pattern_PE', 'fb_Social_PE']

for s in subjects_list: 
    
    sub_output_dir = res_dir + f'/{s}/'
    print(f'running subject {s}')
    if not os.path.isdir(sub_output_dir):
        os.makedirs(sub_output_dir) 

   
    run1 = design_matrices[design_index]
    run2 = design_matrices[design_index + 1]

    # add a new column with 1 for run1 and 0 for run2
    run1['run_regressor'] = 1

    
    # remove "obs_neither" and "fb_neither" columns 
    # comment out if want to model them in the glm
    # if 'obs_Neither' in run1.columns:
    #     run1 = run1.drop(columns=['obs_Neither'], errors='ignore')

    # if 'obs_Neither' in run2.columns:    
    #     run2 = run2.drop(columns=['obs_Neither'], errors='ignore')

    # if 'fb_Neither' in run1.columns:
    #     run1 = run1.drop(columns=['fb_Neither'], errors='ignore')
    # if 'fb_Neither' in run2.columns:
    #     run2 = run2.drop(columns=['fb_Neither'], errors='ignore')
    
    # if the column_names is missing from run1 or run2, add them back with 0  
    for col in column_names:
        if col not in run1.columns:
            run1[col] = 0
        if col not in run2.columns:
            run2[col] = 0

    # concatenate design matrices, fill in zeros for the missing columns
    # Find unique columns
    run1_unique_cols = set(run1.columns) - set(run2.columns)
    run2_unique_cols = set(run2.columns) - set(run1.columns)

    # remove column names in run1_unique_cols if there are in column_names:
    run1_unique_cols = run1_unique_cols - set(column_names)
    run2_unique_cols = run2_unique_cols - set(column_names)

    # Rename unique columns
    run1_renamed = run1.rename(columns={col: f'run1_{col}' for col in run1_unique_cols})
    run2_renamed = run2.rename(columns={col: f'run2_{col}' for col in run2_unique_cols})

    # Concatenate and fill missing values with 0
    concatenated_design = pd.concat([run1_renamed, run2_renamed], ignore_index=True).fillna(0)

    # Concatenate fmri img
    func_path = data_dir + f'sub-{s}_socialpred_run1.nii.gz'
    run1_img = nib.load(func_path)

    func_path = data_dir + f'sub-{s}_socialpred_run2.nii.gz'
    run2_img = nib.load(func_path)
    
    concatenated_imgs = concat_imgs([run1_img, run2_img])

    concat_glm = FirstLevelModel(t_r=TR_Length,
                    noise_model='ar1',
                    standardize=True,
                    hrf_model=None,
                    drift_model='cosine',
                    high_pass=.01, mask_img=gm_mask_img,smoothing_fwhm=6)
    
    concat_glm.fit(concatenated_imgs, design_matrices=concatenated_design)

    plotting.plot_design_matrix(concat_glm.design_matrices_[0], output_file=join(sub_output_dir, f'design_matrix_concatenated.png'))
    concatenated_design.to_csv(join(sub_output_dir, f'sub-{s}_design_matrix_concatenated.csv'))
    
    # compute contrast
    contrast_matrix = np.eye(concatenated_design.shape[1])
    
    # extract the betas
    for i in range(8):
        print(f'saving regressor for video {concatenated_design.columns[i]}')
        eff = concat_glm.compute_contrast(contrast_matrix[i],output_type='effect_size') #parameter estimate
        nii_file_path = sub_output_dir + f'sub-{s}_beta_video-{concatenated_design.columns[i]}_gm_masked.nii.gz'
        nib.save(eff, nii_file_path)

        eff = concat_glm.compute_contrast(contrast_matrix[i],output_type='z_score')
        nii_file_path = sub_output_dir + f'sub-{s}_z_score_video-{concatenated_design.columns[i]}_gm_masked.nii.gz'
        nib.save(eff, nii_file_path)

    
    design_index = design_index + 2
# Out:
# running subject 152
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# running subject 179
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 154
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# saving regressor for video surprise_onset
# running subject 158
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 173
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video obs_Pattern
# saving regressor for video pred_onset
# saving regressor for video surprise_onset
# saving regressor for video csf
# saving regressor for video white_matter
# saving regressor for video trans_x
# running subject 153
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 159
# saving regressor for video run1_fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_PE
# saving regressor for video run1_obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# running subject 174
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 162
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 145
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# running subject 143
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# running subject 181
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 144
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 169
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# running subject 146
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# saving regressor for video surprise_onset
# running subject 167
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 161
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 182
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 147
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 166
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# saving regressor for video surprise_onset
# running subject 160
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 185
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# saving regressor for video surprise_onset
# running subject 170
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# saving regressor for video surprise_onset
# running subject 176
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 151
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# running subject 157
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 171
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# saving regressor for video pred_onset
# running subject 177
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 150
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
# running subject 156
# saving regressor for video fb_Neither
# saving regressor for video fb_Pattern_Congruent
# saving regressor for video fb_Pattern_PE
# saving regressor for video fb_Social_Congruent
# saving regressor for video fb_Social_PE
# saving regressor for video obs_Neither
# saving regressor for video obs_Pattern
# saving regressor for video obs_Social
