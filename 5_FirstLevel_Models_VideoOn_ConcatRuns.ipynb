# %% [markdown]
# ## First-Level Analysis: Video-On Model
#
# This notebook keeps the video-on model as a distinct analysis step while reusing the shared first-level GLM pipeline.

# %%
from pathlib import Path
import sys

sys.path.insert(0, str(Path.cwd() / "src"))

from agentprediction import AnalysisConfig

config = AnalysisConfig()
subjects = config.load_subjects()
print("subjects in this analysis:")
print(subjects)
print(f"**** n = {len(subjects)} *****")

# %%
from agentprediction.events import parse_video_on_events
from agentprediction.first_level import fit_concatenated_first_level, fit_run_design_matrices

# %%
model_name = "model_VideoOn"
create_design_matrix = True
shared_columns = ["video_on"]
n_regressors_to_save = 5

# %%
design_matrices = fit_run_design_matrices(
    config=config,
    model_name=model_name,
    subjects=subjects,
    event_parser=parse_video_on_events,
    event_parser_kwargs={"n_tr": config.n_tr, "tr": config.tr},
    create_design_matrix=create_design_matrix,
)

fit_concatenated_first_level(
    config=config,
    model_name=model_name,
    subjects=subjects,
    shared_columns=shared_columns,
    n_regressors_to_save=n_regressors_to_save,
    design_matrices=design_matrices,
)
