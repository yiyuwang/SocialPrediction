# %% [markdown]
# # Figure S7: Neural Activity during video on
# ## First Level Analysis
#
#
#
# *Yiyu Wang 2025 May*

# %%
import os


import glob
import nibabel as nib
import numpy as np
import pandas as pd
import copy

import nilearn
from nilearn import datasets, plotting, image
from nilearn.image import smooth_img, resample_to_img, load_img, concat_imgs, mean_img, resample_img
from nilearn import plotting
from nilearn.masking import apply_mask
from nilearn.input_data import NiftiMasker
from nilearn.glm.first_level import FirstLevelModel
from nilearn.glm.second_level import SecondLevelModel
from scipy.stats import norm


import gzip

import seaborn as sns
import matplotlib.pyplot as plt

from os.path import join
# Out:
# /Users/yiyuwang/anaconda3/envs/neuroimaging_env/lib/python3.7/site-packages/nilearn/__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()
# /Users/yiyuwang/anaconda3/envs/neuroimaging_env/lib/python3.7/site-packages/nilearn/input_data/__init__.py:23: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
print(nilearn.__version__)
# Out:
# 0.10.2

# %%
# local directory set up
#data_dir =base_dir + 'transformed_data_2mm/'

# directory set up for cluster:
# base_dir = '/scratch/wang.yiyu/SocialAbstraction/'
data_dir = '/Users/yiyuwang/Downloads/social_prediction_transformed_data_2mm/'

logfiles_dir = 'Data/logfiles/'
confounds_dir = 'Data/confounds/'
mask_dir = 'masks/'
figures_dir = 'figures/'

subjects_list = pd.read_csv('Data/included_SocialPred_subjects.csv', header=None)
subjects_list = subjects_list[0].values.tolist()
sample_n = len(subjects_list)
print("subjects in this analysis:")
print(subjects_list)
print(f"**** n = {sample_n} *****" )

vmax = 12
TR = .001
N_TR = 675
TR_Length = 0.8
TR_IN_MS = int(TR_Length/TR)


# resample a gray matter mask
gm_mask_img = nib.load(mask_dir + 'gm_mask_icbm152_brain.nii.gz')
confounds_of_interest = ['csf',
                        'white_matter',
                        'trans_x', 
                        'trans_y', 
                        'trans_z',
                        'rot_x',
                        'rot_y',
                        'rot_z','framewise_displacement']
# Out:
# subjects in this analysis:
# [152, 179, 154, 158, 173, 153, 159, 174, 162, 145, 143, 181, 144, 169, 146, 167, 161, 182, 147, 166, 160, 185, 170, 176, 151, 157, 171, 177, 150, 156]
# **** n = 30 *****

# %%
logfile_headers =np.array(['obs_video_name', 'fd_video_name','video_number','trial_condition','run_number','run_condition',
             'obs_video_onset','obs_video_offset','obs_video_duration_method1','obs_video_duration_method2',
             'prediction','prediction_x','prediction_y','prediction_RT','prediction_onset', 
             'fb_video_onset','fb_video_offset','fb_video_duration_method1','fb_video_duration_method2',
             'surprise','surprise_RT','surprise_onset'])

# %%
def AddSteadyStateOutliers(columns_of_interest, all_columns):
    new_columns = copy.deepcopy(columns_of_interest)
    for column in all_columns:
        if 'outlier' in column:
            new_columns.append(column) 
    return new_columns



def CreateConfoundMatrix(confound_file_path, 
                         confounds_of_interest, s, run):
    
    
    confounds = pd.read_csv(confound_file_path, sep='\t')
    confounds_of_interest = AddSteadyStateOutliers(confounds_of_interest, confounds.columns)
    
    cov = confounds[confounds_of_interest]
    cov.values[np.isnan(cov.values)]=0
    return cov


video_key = pd.read_csv('/Users/yiyuwang/Dropbox/Projects/NEU_projects/SocialPrediction/Results/SocialPrediction_video_key.csv')


def get_subjective_prior(prediction, vn, video_key = video_key):
    social_prior = video_key[video_key.vid_num == vn]['Social_correct'].values[0]
    pattern_prior = video_key[video_key.vid_num == vn]['Pattern_correct'].values[0]
    if pattern_prior == 7:
        if prediction == 4 or prediction == 2:
            return 1, 'Pattern'
        elif prediction == social_prior:
            return 2, 'Social'
        else:
            return 0, 'Neither'
    elif pattern_prior == 8:
        if prediction == 3 or prediction == 2:
            return 1, 'Pattern'
        elif prediction == social_prior:
            return 2, 'Social'
        else:
            return 0, 'Neither'
    elif pattern_prior == 6:
        if prediction == 4 or prediction == 1:
            return 1, 'Pattern'
        elif prediction == social_prior:
            return 2, 'Social'
        else:
            return 0, 'Neither'
    else: 
        if prediction == social_prior:
            return 2, 'Social'
        elif prediction == pattern_prior:
            return 1, 'Pattern'
        else:
            return 0, 'Neither'

# %%
def get_condition(cn):
    if cn == 1:
        cat = 'Pattern'
    elif cn == 2:
        cat = 'Social'
    else:
        print('no such Condition number!')
    return cat 

def parse_task_lines(lines, headers):
    for (i, line) in enumerate(lines):
        cols = line.split(' ')


        video_onset = float(cols[int(np.where(headers == 'obs_video_onset')[0])])
        video_offset = float(cols[int(np.where(headers == 'obs_video_offset')[0])])  
        video_duration = video_offset - video_onset
        # print("video onset: ", video_onset)
        # print("video offset: ", video_offset)
        
        fb_video_onset = float(cols[int(np.where(headers == 'fb_video_onset')[0])])
        fb_video_offset = float(cols[int(np.where(headers == 'fb_video_offset')[0])])  
        fb_video_duration = fb_video_offset - fb_video_onset
        # print("fb video onset: ", fb_video_onset)
        # print("fb video offset: ", fb_video_offset)

        run = int(cols[int(np.where(headers == 'run_number')[0])])

        prediction_onset = float(cols[int(np.where(headers == 'prediction_onset')[0])])
        surprise_onset = float(cols[int(np.where(headers == 'surprise_onset')[0])])
        
        # identify the rest period in between videos and ratings
        rest_onset1 = prediction_onset + 4
        rest_duration1 = fb_video_onset - rest_onset1

        

        rest_onset2 = surprise_onset + 4
        # if i reach the 20th or the 40th line, we assume the next line onset is the end of the run
        if i == 19 or i == 39:
            # this is the last trial of the run, we assume the next line onset is the end of the run
            next_line_onset = N_TR * TR_Length
        else:
            next_line_onset = float(lines[i+1].split(' ')[int(np.where(headers == 'obs_video_onset')[0])])
        rest_duration2 = next_line_onset - rest_onset2
        print("trial number: ", i+1)
        print("Interstimuli rest duration 1: ", rest_duration1)
        print("Intertrial rest duration 2: ", rest_duration2)
        
        yield [video_onset, video_duration, 'cue_VideoOn', run]
        yield [fb_video_onset,fb_video_duration, 'fb_VideoOn', run]
        yield [rest_onset1, rest_duration1, 'rest', run]
        yield [rest_onset2, rest_duration2, 'rest', run]
        yield [surprise_onset, 1, 'surprise_onset', run]
        yield [prediction_onset, 1, 'pred_onset', run]



def create_events_dataframe(task_csv, run):   
    task_lines =[]       
    # df = pd.DataFrame(columns=['onset','duration','trial_type'])
    with open(task_csv, 'r') as task_csv_file:
        task_lines.append(list(parse_task_lines(task_csv_file.readlines()[0:], logfile_headers)))

    df = pd.DataFrame(task_lines[0], columns=['onset','duration','trial_type','run'])
    df= df[df['run']==run].drop(columns=['run'])
    return df

# %%
from nilearn.glm.first_level import make_first_level_design_matrix
from nilearn.glm.first_level import compute_regressor
model_name = 'model_VideoOn'
res_dir = f'Results/{model_name}/1stLvl'

create_design_matrix = True
if create_design_matrix: 
    design_matrices = []
    sub_run_list = []
    for s in subjects_list:
        print(f'running subject {s}')
        sub_output_dir = res_dir + f'/{s}/'
        if not os.path.isdir(sub_output_dir):
            os.makedirs(sub_output_dir)
            
        task_file = glob.glob(logfiles_dir + f"/*{s}*edited.txt")
        task_csv = task_file[0]
        
        for run in [1,2]:
            sub_run_list.append(f'sub-{s}_run-{run}')
            events = create_events_dataframe(task_csv, run)

            #get confounds info:
            confounds_str = f'sub-{s}_task-socialpred_run-{run}_desc-confounds_timeseries.tsv'
            cov = CreateConfoundMatrix(confounds_dir + confounds_str, confounds_of_interest, s, run)
            
            fmri_glm = FirstLevelModel(t_r=TR_Length,
                        noise_model='ar3',
                        standardize=True,
                        hrf_model='spm',
                        drift_model='cosine',
                        high_pass=.012, mask_img=gm_mask_img,smoothing_fwhm=6)
            
            func_str = f'sub-{s}_socialpred_run{run}.nii.gz'
            func_path = data_dir + func_str
            fmri_img = nib.load(func_path)
            fmri_glm = fmri_glm.fit(fmri_img, events, confounds=cov)
            
            
            # save design_matrix for every run
            design_matrix = fmri_glm.design_matrices_[0]
            design_matrices.append(design_matrix)
            print(design_matrix.columns)
            plotting.plot_design_matrix(design_matrix, output_file=join(sub_output_dir, f'design_matrix_run{run}.png'))
            design_matrix.to_csv(join(sub_output_dir, f'sub-{s}_run-{run}_design_matrix.csv'))
            
        # save design_matrix
        design_matrix = fmri_glm.design_matrices_[0]
            

    # save design_matrices
    import pickle
    with open(res_dir + 'design_matrices.pkl', 'wb') as f:
        pickle.dump(design_matrices, f)

else: 
    design_matrices = []
    for s in subjects_list:
        sub_output_dir = res_dir + f'/{s}/'
        for run in [1,2]:
            design_matrices.append(pd.read_csv(join(sub_output_dir, f'sub-{s}_run-{run}_design_matrix.csv'), index_col=0))
# Out:
# running subject 152
# trial number:  1
# Interstimuli rest duration 1:  2.0150000000000006
# Intertrial rest duration 2:  1.0330000000000013
# trial number:  2
# Interstimuli rest duration 1:  1.0150000000000006
# Intertrial rest duration 2:  3.0390000000000015
# trial number:  3
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  2.037000000000006
# trial number:  4
# Interstimuli rest duration 1:  1.0160000000000053
# Intertrial rest duration 2:  1.051000000000002
# trial number:  5
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.046999999999997
# trial number:  6
# Interstimuli rest duration 1:  1.0200000000000102
# Intertrial rest duration 2:  2.0319999999999823
# trial number:  7
# Interstimuli rest duration 1:  2.0459999999999923
# Intertrial rest duration 2:  1.0439999999999827
# trial number:  8
# Interstimuli rest duration 1:  2.007000000000005
# Intertrial rest duration 2:  3.032999999999987
# trial number:  9
# Interstimuli rest duration 1:  2.009999999999991
# Intertrial rest duration 2:  1.0390000000000157
# trial number:  10
# Interstimuli rest duration 1:  1.0159999999999911
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  11
# Interstimuli rest duration 1:  2.015999999999991
# Intertrial rest duration 2:  1.0510000000000446
# trial number:  12
# Interstimuli rest duration 1:  1.0150000000000432
# Intertrial rest duration 2:  1.05499999999995
# trial number:  13
# Interstimuli rest duration 1:  2.0130000000000337
# Intertrial rest duration 2:  3.045000000000016
# trial number:  14
# Interstimuli rest duration 1:  1.009999999999991
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  15
# Interstimuli rest duration 1:  1.024000000000001
# Intertrial rest duration 2:  1.0319999999999823
# trial number:  16
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  2.039000000000044
# trial number:  17
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  2.034999999999968
# trial number:  18
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  1.047999999999945
# trial number:  19
# Interstimuli rest duration 1:  2.01400000000001
# Intertrial rest duration 2:  2.048999999999978
# trial number:  20
# Interstimuli rest duration 1:  1.0199999999999818
# Intertrial rest duration 2:  54.56099999999998
# trial number:  21
# Interstimuli rest duration 1:  1.0350000000000037
# Intertrial rest duration 2:  1.051000000000002
# trial number:  22
# Interstimuli rest duration 1:  2.012999999999998
# Intertrial rest duration 2:  1.0450000000000017
# trial number:  23
# Interstimuli rest duration 1:  2.0109999999999957
# Intertrial rest duration 2:  1.0350000000000108
# trial number:  24
# Interstimuli rest duration 1:  1.0060000000000002
# Intertrial rest duration 2:  1.0330000000000013
# trial number:  25
# Interstimuli rest duration 1:  2.0090000000000003
# Intertrial rest duration 2:  2.038000000000011
# trial number:  26
# Interstimuli rest duration 1:  2.0170000000000243
# Intertrial rest duration 2:  1.0360000000000014
# trial number:  27
# Interstimuli rest duration 1:  2.0490000000000066
# Intertrial rest duration 2:  2.048000000000002
# trial number:  28
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  1.0449999999999875
# trial number:  29
# Interstimuli rest duration 1:  2.0109999999999957
# Intertrial rest duration 2:  3.0340000000000202
# trial number:  30
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  2.033999999999992
# trial number:  31
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0370000000000346
# trial number:  32
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.0360000000000014
# trial number:  33
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  34
# Interstimuli rest duration 1:  1.0150000000000432
# Intertrial rest duration 2:  2.045000000000016
# trial number:  35
# Interstimuli rest duration 1:  2.0219999999999914
# Intertrial rest duration 2:  2.031000000000006
# trial number:  36
# Interstimuli rest duration 1:  1.024000000000001
# Intertrial rest duration 2:  3.0430000000000064
# trial number:  37
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  3.0389999999999873
# trial number:  38
# Interstimuli rest duration 1:  1.0159999999999627
# Intertrial rest duration 2:  1.0360000000000014
# trial number:  39
# Interstimuli rest duration 1:  2.0159999999999627
# Intertrial rest duration 2:  3.0329999999999586
# trial number:  40
# Interstimuli rest duration 1:  2.0179999999999154
# Intertrial rest duration 2:  2.104000000000042
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement', 'motion_outlier00',
#        'motion_outlier01', 'motion_outlier02', 'motion_outlier03',
#        'motion_outlier04', 'drift_1', 'drift_2', 'drift_3', 'drift_4',
#        'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9', 'drift_10',
#        'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# trial number:  1
# Interstimuli rest duration 1:  2.0150000000000006
# Intertrial rest duration 2:  1.0330000000000013
# trial number:  2
# Interstimuli rest duration 1:  1.0150000000000006
# Intertrial rest duration 2:  3.0390000000000015
# trial number:  3
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  2.037000000000006
# trial number:  4
# Interstimuli rest duration 1:  1.0160000000000053
# Intertrial rest duration 2:  1.051000000000002
# trial number:  5
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.046999999999997
# trial number:  6
# Interstimuli rest duration 1:  1.0200000000000102
# Intertrial rest duration 2:  2.0319999999999823
# trial number:  7
# Interstimuli rest duration 1:  2.0459999999999923
# Intertrial rest duration 2:  1.0439999999999827
# trial number:  8
# Interstimuli rest duration 1:  2.007000000000005
# Intertrial rest duration 2:  3.032999999999987
# trial number:  9
# Interstimuli rest duration 1:  2.009999999999991
# Intertrial rest duration 2:  1.0390000000000157
# trial number:  10
# Interstimuli rest duration 1:  1.0159999999999911
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  11
# Interstimuli rest duration 1:  2.015999999999991
# Intertrial rest duration 2:  1.0510000000000446
# trial number:  12
# Interstimuli rest duration 1:  1.0150000000000432
# Intertrial rest duration 2:  1.05499999999995
# trial number:  13
# Interstimuli rest duration 1:  2.0130000000000337
# Intertrial rest duration 2:  3.045000000000016
# trial number:  14
# Interstimuli rest duration 1:  1.009999999999991
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  15
# Interstimuli rest duration 1:  1.024000000000001
# Intertrial rest duration 2:  1.0319999999999823
# trial number:  16
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  2.039000000000044
# trial number:  17
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  2.034999999999968
# trial number:  18
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  1.047999999999945
# trial number:  19
# Interstimuli rest duration 1:  2.01400000000001
# Intertrial rest duration 2:  2.048999999999978
# trial number:  20
# Interstimuli rest duration 1:  1.0199999999999818
# Intertrial rest duration 2:  54.56099999999998
# trial number:  21
# Interstimuli rest duration 1:  1.0350000000000037
# Intertrial rest duration 2:  1.051000000000002
# trial number:  22
# Interstimuli rest duration 1:  2.012999999999998
# Intertrial rest duration 2:  1.0450000000000017
# trial number:  23
# Interstimuli rest duration 1:  2.0109999999999957
# Intertrial rest duration 2:  1.0350000000000108
# trial number:  24
# Interstimuli rest duration 1:  1.0060000000000002
# Intertrial rest duration 2:  1.0330000000000013
# trial number:  25
# Interstimuli rest duration 1:  2.0090000000000003
# Intertrial rest duration 2:  2.038000000000011
# trial number:  26
# Interstimuli rest duration 1:  2.0170000000000243
# Intertrial rest duration 2:  1.0360000000000014
# trial number:  27
# Interstimuli rest duration 1:  2.0490000000000066
# Intertrial rest duration 2:  2.048000000000002
# trial number:  28
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  1.0449999999999875
# trial number:  29
# Interstimuli rest duration 1:  2.0109999999999957
# Intertrial rest duration 2:  3.0340000000000202
# trial number:  30
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  2.033999999999992
# trial number:  31
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0370000000000346
# trial number:  32
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.0360000000000014
# trial number:  33
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  34
# Interstimuli rest duration 1:  1.0150000000000432
# Intertrial rest duration 2:  2.045000000000016
# trial number:  35
# Interstimuli rest duration 1:  2.0219999999999914
# Intertrial rest duration 2:  2.031000000000006
# trial number:  36
# Interstimuli rest duration 1:  1.024000000000001
# Intertrial rest duration 2:  3.0430000000000064
# trial number:  37
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  3.0389999999999873
# trial number:  38
# Interstimuli rest duration 1:  1.0159999999999627
# Intertrial rest duration 2:  1.0360000000000014
# trial number:  39
# Interstimuli rest duration 1:  2.0159999999999627
# Intertrial rest duration 2:  3.0329999999999586
# trial number:  40
# Interstimuli rest duration 1:  2.0179999999999154
# Intertrial rest duration 2:  2.104000000000042
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01',
#        'motion_outlier00', 'motion_outlier01', 'motion_outlier02',
#        'motion_outlier03', 'motion_outlier04', 'motion_outlier05',
#        'motion_outlier06', 'motion_outlier07', 'motion_outlier08',
#        'motion_outlier09', 'motion_outlier10', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 179
# trial number:  1
# Interstimuli rest duration 1:  2.0229999999999997
# Intertrial rest duration 2:  1.0409999999999968
# trial number:  2
# Interstimuli rest duration 1:  2.0159999999999982
# Intertrial rest duration 2:  1.0399999999999991
# trial number:  3
# Interstimuli rest duration 1:  1.039999999999992
# Intertrial rest duration 2:  1.0349999999999966
# trial number:  4
# Interstimuli rest duration 1:  2.0150000000000006
# Intertrial rest duration 2:  1.051000000000002
# trial number:  5
# Interstimuli rest duration 1:  1.0150000000000006
# Intertrial rest duration 2:  3.048999999999978
# trial number:  6
# Interstimuli rest duration 1:  2.048000000000002
# Intertrial rest duration 2:  2.0459999999999923
# trial number:  7
# Interstimuli rest duration 1:  2.0109999999999957
# Intertrial rest duration 2:  2.0319999999999823
# trial number:  8
# Interstimuli rest duration 1:  2.0340000000000202
# Intertrial rest duration 2:  1.039999999999992
# trial number:  9
# Interstimuli rest duration 1:  1.007000000000005
# Intertrial rest duration 2:  1.0390000000000157
# trial number:  10
# Interstimuli rest duration 1:  1.0159999999999911
# Intertrial rest duration 2:  1.032999999999987
# trial number:  11
# Interstimuli rest duration 1:  2.0160000000000196
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  12
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  1.032000000000039
# trial number:  13
# Interstimuli rest duration 1:  1.0120000000000005
# Intertrial rest duration 2:  1.0340000000000487
# trial number:  14
# Interstimuli rest duration 1:  1.0569999999999595
# Intertrial rest duration 2:  2.0319999999999823
# trial number:  15
# Interstimuli rest duration 1:  1.0090000000000146
# Intertrial rest duration 2:  3.039000000000044
# trial number:  16
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.0340000000000487
# trial number:  17
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  2.049000000000035
# trial number:  18
# Interstimuli rest duration 1:  1.0149999999999864
# Intertrial rest duration 2:  3.044999999999959
# trial number:  19
# Interstimuli rest duration 1:  2.011000000000024
# Intertrial rest duration 2:  3.0439999999999827
# trial number:  20
# Interstimuli rest duration 1:  1.0090000000000146
# Intertrial rest duration 2:  18.527000000000044
# trial number:  21
# Interstimuli rest duration 1:  1.0259999999999998
# Intertrial rest duration 2:  1.0440000000000005
# trial number:  22
# Interstimuli rest duration 1:  1.0189999999999984
# Intertrial rest duration 2:  1.0379999999999967
# trial number:  23
# Interstimuli rest duration 1:  2.0150000000000006
# Intertrial rest duration 2:  2.034000000000006
# trial number:  24
# Interstimuli rest duration 1:  2.0150000000000006
# Intertrial rest duration 2:  3.0479999999999876
# trial number:  25
# Interstimuli rest duration 1:  1.0459999999999923
# Intertrial rest duration 2:  1.0439999999999827
# trial number:  26
# Interstimuli rest duration 1:  2.02200000000002
# Intertrial rest duration 2:  3.0390000000000157
# trial number:  27
# Interstimuli rest duration 1:  1.007000000000005
# Intertrial rest duration 2:  1.0339999999999918
# trial number:  28
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.037000000000006
# trial number:  29
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  30
# Interstimuli rest duration 1:  1.0339999999999918
# Intertrial rest duration 2:  1.0480000000000587
# trial number:  31
# Interstimuli rest duration 1:  1.0129999999999768
# Intertrial rest duration 2:  2.0459999999999923
# trial number:  32
# Interstimuli rest duration 1:  2.0120000000000005
# Intertrial rest duration 2:  2.0440000000000396
# trial number:  33
# Interstimuli rest duration 1:  1.0079999999999814
# Intertrial rest duration 2:  2.055000000000007
# trial number:  34
# Interstimuli rest duration 1:  2.0079999999999814
# Intertrial rest duration 2:  1.038000000000011
# trial number:  35
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  2.0360000000000014
# trial number:  36
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  37
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  3.048000000000002
# trial number:  38
# Interstimuli rest duration 1:  1.0120000000000005
# Intertrial rest duration 2:  1.0440000000000396
# trial number:  39
# Interstimuli rest duration 1:  2.021000000000015
# Intertrial rest duration 2:  3.0319999999999823
# trial number:  40
# Interstimuli rest duration 1:  2.011000000000024
# Intertrial rest duration 2:  31.68599999999998
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01',
#        'non_steady_state_outlier02', 'motion_outlier00', 'motion_outlier01',
#        'drift_1', 'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6',
#        'drift_7', 'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12',
#        'constant'],
#       dtype='object')
# trial number:  1
# Interstimuli rest duration 1:  2.0229999999999997
# Intertrial rest duration 2:  1.0409999999999968
# trial number:  2
# Interstimuli rest duration 1:  2.0159999999999982
# Intertrial rest duration 2:  1.0399999999999991
# trial number:  3
# Interstimuli rest duration 1:  1.039999999999992
# Intertrial rest duration 2:  1.0349999999999966
# trial number:  4
# Interstimuli rest duration 1:  2.0150000000000006
# Intertrial rest duration 2:  1.051000000000002
# trial number:  5
# Interstimuli rest duration 1:  1.0150000000000006
# Intertrial rest duration 2:  3.048999999999978
# trial number:  6
# Interstimuli rest duration 1:  2.048000000000002
# Intertrial rest duration 2:  2.0459999999999923
# trial number:  7
# Interstimuli rest duration 1:  2.0109999999999957
# Intertrial rest duration 2:  2.0319999999999823
# trial number:  8
# Interstimuli rest duration 1:  2.0340000000000202
# Intertrial rest duration 2:  1.039999999999992
# trial number:  9
# Interstimuli rest duration 1:  1.007000000000005
# Intertrial rest duration 2:  1.0390000000000157
# trial number:  10
# Interstimuli rest duration 1:  1.0159999999999911
# Intertrial rest duration 2:  1.032999999999987
# trial number:  11
# Interstimuli rest duration 1:  2.0160000000000196
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  12
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  1.032000000000039
# trial number:  13
# Interstimuli rest duration 1:  1.0120000000000005
# Intertrial rest duration 2:  1.0340000000000487
# trial number:  14
# Interstimuli rest duration 1:  1.0569999999999595
# Intertrial rest duration 2:  2.0319999999999823
# trial number:  15
# Interstimuli rest duration 1:  1.0090000000000146
# Intertrial rest duration 2:  3.039000000000044
# trial number:  16
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.0340000000000487
# trial number:  17
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  2.049000000000035
# trial number:  18
# Interstimuli rest duration 1:  1.0149999999999864
# Intertrial rest duration 2:  3.044999999999959
# trial number:  19
# Interstimuli rest duration 1:  2.011000000000024
# Intertrial rest duration 2:  3.0439999999999827
# trial number:  20
# Interstimuli rest duration 1:  1.0090000000000146
# Intertrial rest duration 2:  18.527000000000044
# trial number:  21
# Interstimuli rest duration 1:  1.0259999999999998
# Intertrial rest duration 2:  1.0440000000000005
# trial number:  22
# Interstimuli rest duration 1:  1.0189999999999984
# Intertrial rest duration 2:  1.0379999999999967
# trial number:  23
# Interstimuli rest duration 1:  2.0150000000000006
# Intertrial rest duration 2:  2.034000000000006
# trial number:  24
# Interstimuli rest duration 1:  2.0150000000000006
# Intertrial rest duration 2:  3.0479999999999876
# trial number:  25
# Interstimuli rest duration 1:  1.0459999999999923
# Intertrial rest duration 2:  1.0439999999999827
# trial number:  26
# Interstimuli rest duration 1:  2.02200000000002
# Intertrial rest duration 2:  3.0390000000000157
# trial number:  27
# Interstimuli rest duration 1:  1.007000000000005
# Intertrial rest duration 2:  1.0339999999999918
# trial number:  28
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.037000000000006
# trial number:  29
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  30
# Interstimuli rest duration 1:  1.0339999999999918
# Intertrial rest duration 2:  1.0480000000000587
# trial number:  31
# Interstimuli rest duration 1:  1.0129999999999768
# Intertrial rest duration 2:  2.0459999999999923
# trial number:  32
# Interstimuli rest duration 1:  2.0120000000000005
# Intertrial rest duration 2:  2.0440000000000396
# trial number:  33
# Interstimuli rest duration 1:  1.0079999999999814
# Intertrial rest duration 2:  2.055000000000007
# trial number:  34
# Interstimuli rest duration 1:  2.0079999999999814
# Intertrial rest duration 2:  1.038000000000011
# trial number:  35
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  2.0360000000000014
# trial number:  36
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  37
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  3.048000000000002
# trial number:  38
# Interstimuli rest duration 1:  1.0120000000000005
# Intertrial rest duration 2:  1.0440000000000396
# trial number:  39
# Interstimuli rest duration 1:  2.021000000000015
# Intertrial rest duration 2:  3.0319999999999823
# trial number:  40
# Interstimuli rest duration 1:  2.011000000000024
# Intertrial rest duration 2:  31.68599999999998
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01',
#        'non_steady_state_outlier02', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'motion_outlier03', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 154
# trial number:  1
# Interstimuli rest duration 1:  1.0330000000000013
# Intertrial rest duration 2:  1.0350000000000001
# trial number:  2
# Interstimuli rest duration 1:  1.014000000000003
# Intertrial rest duration 2:  3.047000000000004
# trial number:  3
# Interstimuli rest duration 1:  2.0159999999999982
# Intertrial rest duration 2:  2.0430000000000064
# trial number:  4
# Interstimuli rest duration 1:  1.007000000000005
# Intertrial rest duration 2:  1.0420000000000016
# trial number:  5
# Interstimuli rest duration 1:  1.027000000000001
# Intertrial rest duration 2:  1.0319999999999965
# trial number:  6
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0339999999999918
# trial number:  7
# Interstimuli rest duration 1:  2.0349999999999966
# Intertrial rest duration 2:  2.0490000000000066
# trial number:  8
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  1.046999999999997
# trial number:  9
# Interstimuli rest duration 1:  2.015000000000015
# Intertrial rest duration 2:  1.0449999999999875
# trial number:  10
# Interstimuli rest duration 1:  1.009999999999991
# Intertrial rest duration 2:  1.0319999999999823
# trial number:  11
# Interstimuli rest duration 1:  2.0079999999999814
# Intertrial rest duration 2:  3.0410000000000252
# trial number:  12
# Interstimuli rest duration 1:  1.0079999999999814
# Intertrial rest duration 2:  1.0399999999999636
# trial number:  13
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.0359999999999445
# trial number:  14
# Interstimuli rest duration 1:  1.0159999999999627
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  15
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  3.046000000000049
# trial number:  16
# Interstimuli rest duration 1:  2.0120000000000005
# Intertrial rest duration 2:  2.0439999999999827
# trial number:  17
# Interstimuli rest duration 1:  2.009999999999991
# Intertrial rest duration 2:  2.032000000000039
# trial number:  18
# Interstimuli rest duration 1:  2.0090000000000146
# Intertrial rest duration 2:  2.0389999999999873
# trial number:  19
# Interstimuli rest duration 1:  2.015000000000043
# Intertrial rest duration 2:  3.035000000000025
# trial number:  20
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  34.446000000000026
# trial number:  21
# Interstimuli rest duration 1:  1.0350000000000001
# Intertrial rest duration 2:  1.0500000000000043
# trial number:  22
# Interstimuli rest duration 1:  1.0159999999999982
# Intertrial rest duration 2:  1.0480000000000018
# trial number:  23
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  1.0450000000000017
# trial number:  24
# Interstimuli rest duration 1:  2.010000000000005
# Intertrial rest duration 2:  1.031000000000006
# trial number:  25
# Interstimuli rest duration 1:  1.012999999999991
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  26
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0379999999999825
# trial number:  27
# Interstimuli rest duration 1:  1.0159999999999911
# Intertrial rest duration 2:  3.0360000000000014
# trial number:  28
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.051000000000016
# trial number:  29
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  2.042999999999978
# trial number:  30
# Interstimuli rest duration 1:  2.0130000000000052
# Intertrial rest duration 2:  3.0430000000000064
# trial number:  31
# Interstimuli rest duration 1:  1.0059999999999718
# Intertrial rest duration 2:  3.0430000000000064
# trial number:  32
# Interstimuli rest duration 1:  2.007000000000005
# Intertrial rest duration 2:  1.038000000000011
# trial number:  33
# Interstimuli rest duration 1:  2.008000000000038
# Intertrial rest duration 2:  1.0370000000000346
# trial number:  34
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  1.035000000000025
# trial number:  35
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0470000000000255
# trial number:  36
# Interstimuli rest duration 1:  2.0120000000000005
# Intertrial rest duration 2:  3.0459999999999923
# trial number:  37
# Interstimuli rest duration 1:  1.011000000000024
# Intertrial rest duration 2:  2.0330000000000155
# trial number:  38
# Interstimuli rest duration 1:  2.0090000000000146
# Intertrial rest duration 2:  2.040999999999997
# trial number:  39
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  3.038000000000011
# trial number:  40
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  22.576999999999998
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'motion_outlier00', 'drift_1', 'drift_2',
#        'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8',
#        'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# trial number:  1
# Interstimuli rest duration 1:  1.0330000000000013
# Intertrial rest duration 2:  1.0350000000000001
# trial number:  2
# Interstimuli rest duration 1:  1.014000000000003
# Intertrial rest duration 2:  3.047000000000004
# trial number:  3
# Interstimuli rest duration 1:  2.0159999999999982
# Intertrial rest duration 2:  2.0430000000000064
# trial number:  4
# Interstimuli rest duration 1:  1.007000000000005
# Intertrial rest duration 2:  1.0420000000000016
# trial number:  5
# Interstimuli rest duration 1:  1.027000000000001
# Intertrial rest duration 2:  1.0319999999999965
# trial number:  6
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0339999999999918
# trial number:  7
# Interstimuli rest duration 1:  2.0349999999999966
# Intertrial rest duration 2:  2.0490000000000066
# trial number:  8
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  1.046999999999997
# trial number:  9
# Interstimuli rest duration 1:  2.015000000000015
# Intertrial rest duration 2:  1.0449999999999875
# trial number:  10
# Interstimuli rest duration 1:  1.009999999999991
# Intertrial rest duration 2:  1.0319999999999823
# trial number:  11
# Interstimuli rest duration 1:  2.0079999999999814
# Intertrial rest duration 2:  3.0410000000000252
# trial number:  12
# Interstimuli rest duration 1:  1.0079999999999814
# Intertrial rest duration 2:  1.0399999999999636
# trial number:  13
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.0359999999999445
# trial number:  14
# Interstimuli rest duration 1:  1.0159999999999627
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  15
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  3.046000000000049
# trial number:  16
# Interstimuli rest duration 1:  2.0120000000000005
# Intertrial rest duration 2:  2.0439999999999827
# trial number:  17
# Interstimuli rest duration 1:  2.009999999999991
# Intertrial rest duration 2:  2.032000000000039
# trial number:  18
# Interstimuli rest duration 1:  2.0090000000000146
# Intertrial rest duration 2:  2.0389999999999873
# trial number:  19
# Interstimuli rest duration 1:  2.015000000000043
# Intertrial rest duration 2:  3.035000000000025
# trial number:  20
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  34.446000000000026
# trial number:  21
# Interstimuli rest duration 1:  1.0350000000000001
# Intertrial rest duration 2:  1.0500000000000043
# trial number:  22
# Interstimuli rest duration 1:  1.0159999999999982
# Intertrial rest duration 2:  1.0480000000000018
# trial number:  23
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  1.0450000000000017
# trial number:  24
# Interstimuli rest duration 1:  2.010000000000005
# Intertrial rest duration 2:  1.031000000000006
# trial number:  25
# Interstimuli rest duration 1:  1.012999999999991
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  26
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0379999999999825
# trial number:  27
# Interstimuli rest duration 1:  1.0159999999999911
# Intertrial rest duration 2:  3.0360000000000014
# trial number:  28
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.051000000000016
# trial number:  29
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  2.042999999999978
# trial number:  30
# Interstimuli rest duration 1:  2.0130000000000052
# Intertrial rest duration 2:  3.0430000000000064
# trial number:  31
# Interstimuli rest duration 1:  1.0059999999999718
# Intertrial rest duration 2:  3.0430000000000064
# trial number:  32
# Interstimuli rest duration 1:  2.007000000000005
# Intertrial rest duration 2:  1.038000000000011
# trial number:  33
# Interstimuli rest duration 1:  2.008000000000038
# Intertrial rest duration 2:  1.0370000000000346
# trial number:  34
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  1.035000000000025
# trial number:  35
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0470000000000255
# trial number:  36
# Interstimuli rest duration 1:  2.0120000000000005
# Intertrial rest duration 2:  3.0459999999999923
# trial number:  37
# Interstimuli rest duration 1:  1.011000000000024
# Intertrial rest duration 2:  2.0330000000000155
# trial number:  38
# Interstimuli rest duration 1:  2.0090000000000146
# Intertrial rest duration 2:  2.040999999999997
# trial number:  39
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  3.038000000000011
# trial number:  40
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  22.576999999999998
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01',
#        'non_steady_state_outlier02', 'non_steady_state_outlier03', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 158
# trial number:  1
# Interstimuli rest duration 1:  2.024000000000001
# Intertrial rest duration 2:  1.0350000000000001
# trial number:  2
# Interstimuli rest duration 1:  1.0150000000000006
# Intertrial rest duration 2:  3.0429999999999993
# trial number:  3
# Interstimuli rest duration 1:  1.024000000000001
# Intertrial rest duration 2:  2.0330000000000013
# trial number:  4
# Interstimuli rest duration 1:  1.0189999999999912
# Intertrial rest duration 2:  2.036999999999992
# trial number:  5
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  1.0489999999999924
# trial number:  6
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.0319999999999823
# trial number:  7
# Interstimuli rest duration 1:  2.0209999999999866
# Intertrial rest duration 2:  1.0300000000000011
# trial number:  8
# Interstimuli rest duration 1:  2.0200000000000102
# Intertrial rest duration 2:  1.0339999999999918
# trial number:  9
# Interstimuli rest duration 1:  2.0100000000000193
# Intertrial rest duration 2:  1.039999999999992
# trial number:  10
# Interstimuli rest duration 1:  1.0159999999999911
# Intertrial rest duration 2:  3.033999999999992
# trial number:  11
# Interstimuli rest duration 1:  2.0159999999999627
# Intertrial rest duration 2:  3.051999999999964
# trial number:  12
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  2.048999999999978
# trial number:  13
# Interstimuli rest duration 1:  1.0129999999999768
# Intertrial rest duration 2:  1.0329999999999586
# trial number:  14
# Interstimuli rest duration 1:  1.0120000000000005
# Intertrial rest duration 2:  1.04200000000003
# trial number:  15
# Interstimuli rest duration 1:  2.008000000000038
# Intertrial rest duration 2:  3.0399999999999636
# trial number:  16
# Interstimuli rest duration 1:  1.0170000000000528
# Intertrial rest duration 2:  3.0370000000000346
# trial number:  17
# Interstimuli rest duration 1:  2.0190000000000055
# Intertrial rest duration 2:  1.0360000000000014
# trial number:  18
# Interstimuli rest duration 1:  2.0160000000000196
# Intertrial rest duration 2:  1.0319999999999823
# trial number:  19
# Interstimuli rest duration 1:  1.0200000000000387
# Intertrial rest duration 2:  2.0319999999999823
# trial number:  20
# Interstimuli rest duration 1:  1.021000000000015
# Intertrial rest duration 2:  32.331999999999994
# trial number:  21
# Interstimuli rest duration 1:  1.0189999999999984
# Intertrial rest duration 2:  2.032999999999994
# trial number:  22
# Interstimuli rest duration 1:  2.0219999999999985
# Intertrial rest duration 2:  2.0319999999999965
# trial number:  23
# Interstimuli rest duration 1:  2.0109999999999957
# Intertrial rest duration 2:  3.0349999999999966
# trial number:  24
# Interstimuli rest duration 1:  1.0160000000000053
# Intertrial rest duration 2:  1.036999999999992
# trial number:  25
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.0509999999999877
# trial number:  26
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  1.032999999999987
# trial number:  27
# Interstimuli rest duration 1:  1.0150000000000148
# Intertrial rest duration 2:  2.030000000000001
# trial number:  28
# Interstimuli rest duration 1:  1.0219999999999914
# Intertrial rest duration 2:  3.033999999999992
# trial number:  29
# Interstimuli rest duration 1:  1.0229999999999961
# Intertrial rest duration 2:  1.0339999999999918
# trial number:  30
# Interstimuli rest duration 1:  2.009999999999991
# Intertrial rest duration 2:  1.0389999999999873
# trial number:  31
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  3.034999999999968
# trial number:  32
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  2.0499999999999545
# trial number:  33
# Interstimuli rest duration 1:  2.0160000000000196
# Intertrial rest duration 2:  1.0480000000000018
# trial number:  34
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  1.0459999999999923
# trial number:  35
# Interstimuli rest duration 1:  1.0109999999999673
# Intertrial rest duration 2:  3.0430000000000064
# trial number:  36
# Interstimuli rest duration 1:  2.0090000000000146
# Intertrial rest duration 2:  1.0419999999999732
# trial number:  37
# Interstimuli rest duration 1:  2.005999999999972
# Intertrial rest duration 2:  3.035000000000025
# trial number:  38
# Interstimuli rest duration 1:  2.0179999999999723
# Intertrial rest duration 2:  1.035000000000025
# trial number:  39
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0329999999999586
# trial number:  40
# Interstimuli rest duration 1:  1.0190000000000055
# Intertrial rest duration 2:  23.229000000000042
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01',
#        'non_steady_state_outlier02', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'motion_outlier03', 'motion_outlier04', 'drift_1',
#        'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7',
#        'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# trial number:  1
# Interstimuli rest duration 1:  2.024000000000001
# Intertrial rest duration 2:  1.0350000000000001
# trial number:  2
# Interstimuli rest duration 1:  1.0150000000000006
# Intertrial rest duration 2:  3.0429999999999993
# trial number:  3
# Interstimuli rest duration 1:  1.024000000000001
# Intertrial rest duration 2:  2.0330000000000013
# trial number:  4
# Interstimuli rest duration 1:  1.0189999999999912
# Intertrial rest duration 2:  2.036999999999992
# trial number:  5
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  1.0489999999999924
# trial number:  6
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.0319999999999823
# trial number:  7
# Interstimuli rest duration 1:  2.0209999999999866
# Intertrial rest duration 2:  1.0300000000000011
# trial number:  8
# Interstimuli rest duration 1:  2.0200000000000102
# Intertrial rest duration 2:  1.0339999999999918
# trial number:  9
# Interstimuli rest duration 1:  2.0100000000000193
# Intertrial rest duration 2:  1.039999999999992
# trial number:  10
# Interstimuli rest duration 1:  1.0159999999999911
# Intertrial rest duration 2:  3.033999999999992
# trial number:  11
# Interstimuli rest duration 1:  2.0159999999999627
# Intertrial rest duration 2:  3.051999999999964
# trial number:  12
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  2.048999999999978
# trial number:  13
# Interstimuli rest duration 1:  1.0129999999999768
# Intertrial rest duration 2:  1.0329999999999586
# trial number:  14
# Interstimuli rest duration 1:  1.0120000000000005
# Intertrial rest duration 2:  1.04200000000003
# trial number:  15
# Interstimuli rest duration 1:  2.008000000000038
# Intertrial rest duration 2:  3.0399999999999636
# trial number:  16
# Interstimuli rest duration 1:  1.0170000000000528
# Intertrial rest duration 2:  3.0370000000000346
# trial number:  17
# Interstimuli rest duration 1:  2.0190000000000055
# Intertrial rest duration 2:  1.0360000000000014
# trial number:  18
# Interstimuli rest duration 1:  2.0160000000000196
# Intertrial rest duration 2:  1.0319999999999823
# trial number:  19
# Interstimuli rest duration 1:  1.0200000000000387
# Intertrial rest duration 2:  2.0319999999999823
# trial number:  20
# Interstimuli rest duration 1:  1.021000000000015
# Intertrial rest duration 2:  32.331999999999994
# trial number:  21
# Interstimuli rest duration 1:  1.0189999999999984
# Intertrial rest duration 2:  2.032999999999994
# trial number:  22
# Interstimuli rest duration 1:  2.0219999999999985
# Intertrial rest duration 2:  2.0319999999999965
# trial number:  23
# Interstimuli rest duration 1:  2.0109999999999957
# Intertrial rest duration 2:  3.0349999999999966
# trial number:  24
# Interstimuli rest duration 1:  1.0160000000000053
# Intertrial rest duration 2:  1.036999999999992
# trial number:  25
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.0509999999999877
# trial number:  26
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  1.032999999999987
# trial number:  27
# Interstimuli rest duration 1:  1.0150000000000148
# Intertrial rest duration 2:  2.030000000000001
# trial number:  28
# Interstimuli rest duration 1:  1.0219999999999914
# Intertrial rest duration 2:  3.033999999999992
# trial number:  29
# Interstimuli rest duration 1:  1.0229999999999961
# Intertrial rest duration 2:  1.0339999999999918
# trial number:  30
# Interstimuli rest duration 1:  2.009999999999991
# Intertrial rest duration 2:  1.0389999999999873
# trial number:  31
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  3.034999999999968
# trial number:  32
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  2.0499999999999545
# trial number:  33
# Interstimuli rest duration 1:  2.0160000000000196
# Intertrial rest duration 2:  1.0480000000000018
# trial number:  34
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  1.0459999999999923
# trial number:  35
# Interstimuli rest duration 1:  1.0109999999999673
# Intertrial rest duration 2:  3.0430000000000064
# trial number:  36
# Interstimuli rest duration 1:  2.0090000000000146
# Intertrial rest duration 2:  1.0419999999999732
# trial number:  37
# Interstimuli rest duration 1:  2.005999999999972
# Intertrial rest duration 2:  3.035000000000025
# trial number:  38
# Interstimuli rest duration 1:  2.0179999999999723
# Intertrial rest duration 2:  1.035000000000025
# trial number:  39
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0329999999999586
# trial number:  40
# Interstimuli rest duration 1:  1.0190000000000055
# Intertrial rest duration 2:  23.229000000000042
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01',
#        'non_steady_state_outlier02', 'motion_outlier00', 'drift_1', 'drift_2',
#        'drift_3', 'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8',
#        'drift_9', 'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# running subject 173
# trial number:  1
# Interstimuli rest duration 1:  2.030000000000001
# Intertrial rest duration 2:  1.0400000000000027
# trial number:  2
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.0530000000000044
# trial number:  3
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.0490000000000066
# trial number:  4
# Interstimuli rest duration 1:  2.013999999999996
# Intertrial rest duration 2:  1.0460000000000065
# trial number:  5
# Interstimuli rest duration 1:  1.009999999999991
# Intertrial rest duration 2:  3.0420000000000016
# trial number:  6
# Interstimuli rest duration 1:  2.0080000000000098
# Intertrial rest duration 2:  1.0410000000000252
# trial number:  7
# Interstimuli rest duration 1:  2.008999999999986
# Intertrial rest duration 2:  1.0400000000000205
# trial number:  8
# Interstimuli rest duration 1:  1.0180000000000007
# Intertrial rest duration 2:  2.037000000000006
# trial number:  9
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.049999999999983
# trial number:  10
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  1.049999999999983
# trial number:  11
# Interstimuli rest duration 1:  1.0130000000000337
# Intertrial rest duration 2:  1.044999999999959
# trial number:  12
# Interstimuli rest duration 1:  1.0090000000000146
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  13
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.037999999999954
# trial number:  14
# Interstimuli rest duration 1:  2.021000000000015
# Intertrial rest duration 2:  3.034999999999968
# trial number:  15
# Interstimuli rest duration 1:  1.018000000000029
# Intertrial rest duration 2:  1.052000000000021
# trial number:  16
# Interstimuli rest duration 1:  1.0149999999999864
# Intertrial rest duration 2:  1.0489999999999782
# trial number:  17
# Interstimuli rest duration 1:  1.0120000000000005
# Intertrial rest duration 2:  2.045000000000016
# trial number:  18
# Interstimuli rest duration 1:  2.0120000000000005
# Intertrial rest duration 2:  2.04200000000003
# trial number:  19
# Interstimuli rest duration 1:  2.0079999999999814
# Intertrial rest duration 2:  3.0400000000000205
# trial number:  20
# Interstimuli rest duration 1:  1.0159999999999627
# Intertrial rest duration 2:  25.979000000000042
# trial number:  21
# Interstimuli rest duration 1:  2.022000000000002
# Intertrial rest duration 2:  2.035
# trial number:  22
# Interstimuli rest duration 1:  2.0090000000000003
# Intertrial rest duration 2:  1.0429999999999993
# trial number:  23
# Interstimuli rest duration 1:  1.0180000000000007
# Intertrial rest duration 2:  1.036999999999992
# trial number:  24
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  2.034000000000006
# trial number:  25
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.0490000000000066
# trial number:  26
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  3.0459999999999923
# trial number:  27
# Interstimuli rest duration 1:  2.0219999999999914
# Intertrial rest duration 2:  1.0339999999999918
# trial number:  28
# Interstimuli rest duration 1:  2.0660000000000025
# Intertrial rest duration 2:  1.032999999999987
# trial number:  29
# Interstimuli rest duration 1:  1.0180000000000007
# Intertrial rest duration 2:  1.0400000000000205
# trial number:  30
# Interstimuli rest duration 1:  1.0170000000000243
# Intertrial rest duration 2:  1.0360000000000014
# trial number:  31
# Interstimuli rest duration 1:  1.0190000000000055
# Intertrial rest duration 2:  1.0509999999999877
# trial number:  32
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0469999999999686
# trial number:  33
# Interstimuli rest duration 1:  1.0149999999999864
# Intertrial rest duration 2:  3.046000000000049
# trial number:  34
# Interstimuli rest duration 1:  2.011000000000024
# Intertrial rest duration 2:  2.0440000000000396
# trial number:  35
# Interstimuli rest duration 1:  2.019999999999982
# Intertrial rest duration 2:  3.0329999999999586
# trial number:  36
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  2.038000000000011
# trial number:  37
# Interstimuli rest duration 1:  1.0159999999999627
# Intertrial rest duration 2:  2.035000000000025
# trial number:  38
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  1.0509999999999877
# trial number:  39
# Interstimuli rest duration 1:  2.0159999999999627
# Intertrial rest duration 2:  1.0480000000000018
# trial number:  40
# Interstimuli rest duration 1:  2.0109999999999673
# Intertrial rest duration 2:  37.63900000000001
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'motion_outlier03', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# trial number:  1
# Interstimuli rest duration 1:  2.030000000000001
# Intertrial rest duration 2:  1.0400000000000027
# trial number:  2
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.0530000000000044
# trial number:  3
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.0490000000000066
# trial number:  4
# Interstimuli rest duration 1:  2.013999999999996
# Intertrial rest duration 2:  1.0460000000000065
# trial number:  5
# Interstimuli rest duration 1:  1.009999999999991
# Intertrial rest duration 2:  3.0420000000000016
# trial number:  6
# Interstimuli rest duration 1:  2.0080000000000098
# Intertrial rest duration 2:  1.0410000000000252
# trial number:  7
# Interstimuli rest duration 1:  2.008999999999986
# Intertrial rest duration 2:  1.0400000000000205
# trial number:  8
# Interstimuli rest duration 1:  1.0180000000000007
# Intertrial rest duration 2:  2.037000000000006
# trial number:  9
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.049999999999983
# trial number:  10
# Interstimuli rest duration 1:  2.0149999999999864
# Intertrial rest duration 2:  1.049999999999983
# trial number:  11
# Interstimuli rest duration 1:  1.0130000000000337
# Intertrial rest duration 2:  1.044999999999959
# trial number:  12
# Interstimuli rest duration 1:  1.0090000000000146
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  13
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.037999999999954
# trial number:  14
# Interstimuli rest duration 1:  2.021000000000015
# Intertrial rest duration 2:  3.034999999999968
# trial number:  15
# ...
# Intertrial rest duration 2:  17.408999999999992
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01',
#        'motion_outlier00', 'drift_1', 'drift_2', 'drift_3', 'drift_4',
#        'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9', 'drift_10',
#        'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# trial number:  1
# Interstimuli rest duration 1:  1.0350000000000001
# Intertrial rest duration 2:  1.051000000000002
# trial number:  2
# Interstimuli rest duration 1:  2.0159999999999982
# Intertrial rest duration 2:  1.0479999999999947
# trial number:  3
# Interstimuli rest duration 1:  2.046999999999997
# Intertrial rest duration 2:  3.0330000000000013
# trial number:  4
# Interstimuli rest duration 1:  2.0460000000000065
# Intertrial rest duration 2:  3.0759999999999934
# trial number:  5
# Interstimuli rest duration 1:  2.0260000000000105
# Intertrial rest duration 2:  3.0420000000000016
# trial number:  6
# Interstimuli rest duration 1:  2.037000000000006
# Intertrial rest duration 2:  3.0379999999999825
# trial number:  7
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  1.0519999999999925
# trial number:  8
# Interstimuli rest duration 1:  2.015999999999991
# Intertrial rest duration 2:  1.0489999999999782
# trial number:  9
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  2.0449999999999875
# trial number:  10
# Interstimuli rest duration 1:  1.0109999999999957
# Intertrial rest duration 2:  1.045000000000016
# trial number:  11
# Interstimuli rest duration 1:  1.0090000000000146
# Intertrial rest duration 2:  2.0990000000000464
# trial number:  12
# Interstimuli rest duration 1:  1.0160000000000196
# Intertrial rest duration 2:  1.0400000000000205
# trial number:  13
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  1.0360000000000014
# trial number:  14
# Interstimuli rest duration 1:  1.0509999999999877
# Intertrial rest duration 2:  2.1509999999999536
# trial number:  15
# Interstimuli rest duration 1:  1.0150000000000432
# Intertrial rest duration 2:  2.048999999999978
# trial number:  16
# Interstimuli rest duration 1:  1.0129999999999768
# Intertrial rest duration 2:  1.0469999999999686
# trial number:  17
# Interstimuli rest duration 1:  2.009999999999991
# Intertrial rest duration 2:  1.025000000000034
# trial number:  18
# Interstimuli rest duration 1:  1.0089999999999577
# Intertrial rest duration 2:  3.040999999999997
# trial number:  19
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  1.0370000000000346
# trial number:  20
# Interstimuli rest duration 1:  1.0159999999999627
# Intertrial rest duration 2:  41.610000000000014
# trial number:  21
# Interstimuli rest duration 1:  1.033999999999999
# Intertrial rest duration 2:  1.0350000000000001
# trial number:  22
# Interstimuli rest duration 1:  2.0150000000000006
# Intertrial rest duration 2:  3.0459999999999994
# trial number:  23
# Interstimuli rest duration 1:  2.0130000000000052
# Intertrial rest duration 2:  1.043999999999997
# trial number:  24
# Interstimuli rest duration 1:  2.0659999999999883
# Intertrial rest duration 2:  2.0319999999999965
# trial number:  25
# Interstimuli rest duration 1:  1.0090000000000003
# Intertrial rest duration 2:  2.0390000000000015
# trial number:  26
# Interstimuli rest duration 1:  1.0159999999999911
# Intertrial rest duration 2:  3.0349999999999966
# trial number:  27
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.049999999999983
# trial number:  28
# Interstimuli rest duration 1:  2.0160000000000196
# Intertrial rest duration 2:  1.0480000000000018
# trial number:  29
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  1.046999999999997
# trial number:  30
# Interstimuli rest duration 1:  1.0459999999999923
# Intertrial rest duration 2:  2.0420000000000016
# trial number:  31
# Interstimuli rest duration 1:  2.024000000000001
# Intertrial rest duration 2:  2.0329999999999586
# trial number:  32
# Interstimuli rest duration 1:  1.0089999999999577
# Intertrial rest duration 2:  1.0369999999999777
# trial number:  33
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  1.0360000000000014
# trial number:  34
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  2.048000000000002
# trial number:  35
# Interstimuli rest duration 1:  1.01400000000001
# Intertrial rest duration 2:  3.0470000000000255
# trial number:  36
# Interstimuli rest duration 1:  1.011000000000024
# Intertrial rest duration 2:  3.0430000000000064
# trial number:  37
# Interstimuli rest duration 1:  2.0079999999999814
# Intertrial rest duration 2:  1.0470000000000255
# trial number:  38
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.039000000000044
# trial number:  39
# Interstimuli rest duration 1:  2.0160000000000196
# Intertrial rest duration 2:  1.0340000000000487
# trial number:  40
# Interstimuli rest duration 1:  1.0509999999999877
# Intertrial rest duration 2:  17.408999999999992
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'motion_outlier00', 'motion_outlier01',
#        'drift_1', 'drift_2', 'drift_3', 'drift_4', 'drift_5', 'drift_6',
#        'drift_7', 'drift_8', 'drift_9', 'drift_10', 'drift_11', 'drift_12',
#        'constant'],
#       dtype='object')
# running subject 156
# trial number:  1
# Interstimuli rest duration 1:  1.0250000000000021
# Intertrial rest duration 2:  1.0420000000000016
# trial number:  2
# Interstimuli rest duration 1:  1.017000000000003
# Intertrial rest duration 2:  2.0390000000000015
# trial number:  3
# Interstimuli rest duration 1:  2.0260000000000105
# Intertrial rest duration 2:  1.0349999999999966
# trial number:  4
# Interstimuli rest duration 1:  2.010000000000005
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  5
# Interstimuli rest duration 1:  1.0490000000000066
# Intertrial rest duration 2:  2.0489999999999924
# trial number:  6
# Interstimuli rest duration 1:  1.0120000000000005
# Intertrial rest duration 2:  1.0459999999999923
# trial number:  7
# Interstimuli rest duration 1:  1.021000000000015
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  8
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.041999999999973
# trial number:  9
# Interstimuli rest duration 1:  2.0080000000000098
# Intertrial rest duration 2:  1.0370000000000061
# trial number:  10
# Interstimuli rest duration 1:  2.015999999999991
# Intertrial rest duration 2:  1.0349999999999966
# trial number:  11
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  12
# Interstimuli rest duration 1:  1.01400000000001
# Intertrial rest duration 2:  3.0459999999999923
# trial number:  13
# Interstimuli rest duration 1:  2.0109999999999673
# Intertrial rest duration 2:  2.0440000000000396
# trial number:  14
# Interstimuli rest duration 1:  2.0079999999999814
# Intertrial rest duration 2:  1.0409999999999968
# trial number:  15
# Interstimuli rest duration 1:  2.0159999999999627
# Intertrial rest duration 2:  1.037999999999954
# trial number:  16
# Interstimuli rest duration 1:  2.0360000000000014
# Intertrial rest duration 2:  2.0369999999999777
# trial number:  17
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.032000000000039
# trial number:  18
# Interstimuli rest duration 1:  1.021000000000015
# Intertrial rest duration 2:  3.0360000000000014
# trial number:  19
# Interstimuli rest duration 1:  1.0230000000000246
# Intertrial rest duration 2:  2.026999999999987
# trial number:  20
# Interstimuli rest duration 1:  1.0069999999999482
# Intertrial rest duration 2:  36.791
# trial number:  21
# Interstimuli rest duration 1:  2.0249999999999986
# Intertrial rest duration 2:  1.0440000000000005
# trial number:  22
# Interstimuli rest duration 1:  2.0159999999999982
# Intertrial rest duration 2:  2.039999999999999
# trial number:  23
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.034000000000006
# trial number:  24
# Interstimuli rest duration 1:  1.0150000000000006
# Intertrial rest duration 2:  2.0490000000000066
# trial number:  25
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  1.0309999999999775
# trial number:  26
# Interstimuli rest duration 1:  2.0139999999999816
# Intertrial rest duration 2:  1.0449999999999875
# trial number:  27
# Interstimuli rest duration 1:  1.024000000000001
# Intertrial rest duration 2:  3.0420000000000016
# trial number:  28
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.0420000000000016
# trial number:  29
# Interstimuli rest duration 1:  2.015999999999991
# Intertrial rest duration 2:  1.0370000000000061
# trial number:  30
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  31
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  2.034999999999968
# trial number:  32
# Interstimuli rest duration 1:  2.019999999999982
# Intertrial rest duration 2:  2.0330000000000155
# trial number:  33
# Interstimuli rest duration 1:  1.024000000000001
# Intertrial rest duration 2:  1.0329999999999586
# trial number:  34
# Interstimuli rest duration 1:  2.0060000000000286
# Intertrial rest duration 2:  2.041999999999973
# trial number:  35
# Interstimuli rest duration 1:  2.0189999999999486
# Intertrial rest duration 2:  3.039000000000044
# trial number:  36
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  1.0340000000000487
# trial number:  37
# Interstimuli rest duration 1:  1.0150000000000432
# Intertrial rest duration 2:  1.0550000000000068
# trial number:  38
# Interstimuli rest duration 1:  1.01400000000001
# Intertrial rest duration 2:  1.0470000000000255
# trial number:  39
# Interstimuli rest duration 1:  1.0130000000000337
# Intertrial rest duration 2:  3.0439999999999827
# trial number:  40
# Interstimuli rest duration 1:  2.0079999999999814
# Intertrial rest duration 2:  30.661999999999978
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'non_steady_state_outlier01',
#        'motion_outlier00', 'motion_outlier01', 'motion_outlier02',
#        'motion_outlier03', 'motion_outlier04', 'motion_outlier05',
#        'motion_outlier06', 'motion_outlier07', 'motion_outlier08',
#        'motion_outlier09', 'motion_outlier10', 'drift_1', 'drift_2', 'drift_3',
#        'drift_4', 'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9',
#        'drift_10', 'drift_11', 'drift_12', 'constant'],
#       dtype='object')
# trial number:  1
# Interstimuli rest duration 1:  1.0250000000000021
# Intertrial rest duration 2:  1.0420000000000016
# trial number:  2
# Interstimuli rest duration 1:  1.017000000000003
# Intertrial rest duration 2:  2.0390000000000015
# trial number:  3
# Interstimuli rest duration 1:  2.0260000000000105
# Intertrial rest duration 2:  1.0349999999999966
# trial number:  4
# Interstimuli rest duration 1:  2.010000000000005
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  5
# Interstimuli rest duration 1:  1.0490000000000066
# Intertrial rest duration 2:  2.0489999999999924
# trial number:  6
# Interstimuli rest duration 1:  1.0120000000000005
# Intertrial rest duration 2:  1.0459999999999923
# trial number:  7
# Interstimuli rest duration 1:  1.021000000000015
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  8
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.041999999999973
# trial number:  9
# Interstimuli rest duration 1:  2.0080000000000098
# Intertrial rest duration 2:  1.0370000000000061
# trial number:  10
# Interstimuli rest duration 1:  2.015999999999991
# Intertrial rest duration 2:  1.0349999999999966
# trial number:  11
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  1.0500000000000114
# trial number:  12
# Interstimuli rest duration 1:  1.01400000000001
# Intertrial rest duration 2:  3.0459999999999923
# trial number:  13
# Interstimuli rest duration 1:  2.0109999999999673
# Intertrial rest duration 2:  2.0440000000000396
# trial number:  14
# Interstimuli rest duration 1:  2.0079999999999814
# Intertrial rest duration 2:  1.0409999999999968
# trial number:  15
# Interstimuli rest duration 1:  2.0159999999999627
# Intertrial rest duration 2:  1.037999999999954
# trial number:  16
# Interstimuli rest duration 1:  2.0360000000000014
# Intertrial rest duration 2:  2.0369999999999777
# trial number:  17
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.032000000000039
# trial number:  18
# Interstimuli rest duration 1:  1.021000000000015
# Intertrial rest duration 2:  3.0360000000000014
# trial number:  19
# Interstimuli rest duration 1:  1.0230000000000246
# Intertrial rest duration 2:  2.026999999999987
# trial number:  20
# Interstimuli rest duration 1:  1.0069999999999482
# Intertrial rest duration 2:  36.791
# trial number:  21
# Interstimuli rest duration 1:  2.0249999999999986
# Intertrial rest duration 2:  1.0440000000000005
# trial number:  22
# Interstimuli rest duration 1:  2.0159999999999982
# Intertrial rest duration 2:  2.039999999999999
# trial number:  23
# Interstimuli rest duration 1:  2.016999999999996
# Intertrial rest duration 2:  3.034000000000006
# trial number:  24
# Interstimuli rest duration 1:  1.0150000000000006
# Intertrial rest duration 2:  2.0490000000000066
# trial number:  25
# Interstimuli rest duration 1:  1.0130000000000052
# Intertrial rest duration 2:  1.0309999999999775
# trial number:  26
# Interstimuli rest duration 1:  2.0139999999999816
# Intertrial rest duration 2:  1.0449999999999875
# trial number:  27
# Interstimuli rest duration 1:  1.024000000000001
# Intertrial rest duration 2:  3.0420000000000016
# trial number:  28
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  3.0420000000000016
# trial number:  29
# Interstimuli rest duration 1:  2.015999999999991
# Intertrial rest duration 2:  1.0370000000000061
# trial number:  30
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  1.0330000000000155
# trial number:  31
# Interstimuli rest duration 1:  1.016999999999996
# Intertrial rest duration 2:  2.034999999999968
# trial number:  32
# Interstimuli rest duration 1:  2.019999999999982
# Intertrial rest duration 2:  2.0330000000000155
# trial number:  33
# Interstimuli rest duration 1:  1.024000000000001
# Intertrial rest duration 2:  1.0329999999999586
# trial number:  34
# Interstimuli rest duration 1:  2.0060000000000286
# Intertrial rest duration 2:  2.041999999999973
# trial number:  35
# Interstimuli rest duration 1:  2.0189999999999486
# Intertrial rest duration 2:  3.039000000000044
# trial number:  36
# Interstimuli rest duration 1:  2.018000000000029
# Intertrial rest duration 2:  1.0340000000000487
# trial number:  37
# Interstimuli rest duration 1:  1.0150000000000432
# Intertrial rest duration 2:  1.0550000000000068
# trial number:  38
# Interstimuli rest duration 1:  1.01400000000001
# Intertrial rest duration 2:  1.0470000000000255
# trial number:  39
# Interstimuli rest duration 1:  1.0130000000000337
# Intertrial rest duration 2:  3.0439999999999827
# trial number:  40
# Interstimuli rest duration 1:  2.0079999999999814
# Intertrial rest duration 2:  30.661999999999978
# Index(['cue_VideoOn', 'fb_VideoOn', 'pred_onset', 'rest', 'surprise_onset',
#        'csf', 'white_matter', 'trans_x', 'trans_y', 'trans_z', 'rot_x',
#        'rot_y', 'rot_z', 'framewise_displacement',
#        'non_steady_state_outlier00', 'motion_outlier00', 'motion_outlier01',
#        'motion_outlier02', 'drift_1', 'drift_2', 'drift_3', 'drift_4',
#        'drift_5', 'drift_6', 'drift_7', 'drift_8', 'drift_9', 'drift_10',
#        'drift_11', 'drift_12', 'constant'],
#       dtype='object')

# %%
dm_dir = f'Results/{model_name}/1stLvl'

design_matrices = []
for s in subjects_list:
    sub_output_dir = dm_dir + f'/{s}/'
    for run in [1,2]:
        design_matrices.append(pd.read_csv(join(sub_output_dir, f'sub-{s}_run-{run}_design_matrix.csv'), index_col=0))

            
design_index = 0

res_dir = f'Results/{model_name}/1stLvl'
if not os.path.isdir(res_dir):
    os.makedirs(res_dir)
column_names = ['video_on']

for s in subjects_list: 
    
    sub_output_dir = res_dir + f'/{s}/'
    print(f'running subject {s}')
    if not os.path.isdir(sub_output_dir):
        os.makedirs(sub_output_dir) 

   
    run1 = design_matrices[design_index]
    run2 = design_matrices[design_index + 1]

    # add a new column with 1 for run1 and 0 for run2
    run1['run_regressor'] = 1

    

    # concatenate design matrices, fill in zeros for the missing columns
    # Find unique columns
    run1_unique_cols = set(run1.columns) - set(run2.columns)
    run2_unique_cols = set(run2.columns) - set(run1.columns)

    # remove column names in run1_unique_cols if there are in column_names:
    run1_unique_cols = run1_unique_cols - set(column_names)
    run2_unique_cols = run2_unique_cols - set(column_names)

    # Rename unique columns
    run1_renamed = run1.rename(columns={col: f'run1_{col}' for col in run1_unique_cols})
    run2_renamed = run2.rename(columns={col: f'run2_{col}' for col in run2_unique_cols})

    # Concatenate and fill missing values with 0
    concatenated_design = pd.concat([run1_renamed, run2_renamed], ignore_index=True).fillna(0)

    # Concatenate fmri img
    func_path = data_dir + f'sub-{s}_socialpred_run1.nii.gz'
    run1_img = nib.load(func_path)

    func_path = data_dir + f'sub-{s}_socialpred_run2.nii.gz'
    run2_img = nib.load(func_path)
    
    concatenated_imgs = concat_imgs([run1_img, run2_img])

    concat_glm = FirstLevelModel(t_r=TR_Length,
                    noise_model='ar1',
                    standardize=True,
                    hrf_model=None,
                    drift_model='cosine',
                    high_pass=.01, mask_img=gm_mask_img,smoothing_fwhm=6)
    
    concat_glm.fit(concatenated_imgs, design_matrices=concatenated_design)

    plotting.plot_design_matrix(concat_glm.design_matrices_[0], output_file=join(sub_output_dir, f'design_matrix_concatenated.png'))
    concatenated_design.to_csv(join(sub_output_dir, f'sub-{s}_design_matrix_concatenated.csv'))
    
    # compute contrast
    contrast_matrix = np.eye(concatenated_design.shape[1])
    
    # extract the betas
    for i in range(5):
        print(f'saving regressor for video {concatenated_design.columns[i]}')
        eff = concat_glm.compute_contrast(contrast_matrix[i],output_type='effect_size') #parameter estimate
        nii_file_path = sub_output_dir + f'sub-{s}_beta_video-{concatenated_design.columns[i]}_gm_masked.nii.gz'
        nib.save(eff, nii_file_path)

        eff = concat_glm.compute_contrast(contrast_matrix[i],output_type='z_score')
        nii_file_path = sub_output_dir + f'sub-{s}_z_score_video-{concatenated_design.columns[i]}_gm_masked.nii.gz'
        nib.save(eff, nii_file_path)

    
    design_index = design_index + 2
# Out:
# running subject 152
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 179
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 154
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 158
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 173
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 153
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 159
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 174
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 162
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 145
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 143
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 181
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 144
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 169
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 146
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 167
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 161
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 182
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 147
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 166
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 160
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 185
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 170
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 176
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 151
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 157
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 171
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 177
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 150
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
# running subject 156
# saving regressor for video cue_VideoOn
# saving regressor for video fb_VideoOn
# saving regressor for video pred_onset
# saving regressor for video rest
# saving regressor for video surprise_onset
